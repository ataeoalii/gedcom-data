# %% [markdown]
# # Overview
# This Python notebook gives a few basic insights into your genealogy by answering a few very high-level questions about the data you import.
#
# ## Getting Started
# To use this notebook, input a file path to your gedcom file in the first cell.

# %%
from parser import parse_file
import pandas as pd

# Path to your `.ged` file
file_path = input() # TODO: Paste a path to your gedcom file here
pgraph = parse_file(file_path)

print("Data imported")

df = pd.DataFrame([p.df() for p in pgraph.values()], columns=[
    'name',
    'birth_date',
    'birth_place',
    'death_date',
    'death_place',
    'sex',
    'child_count',
    'years_lived',
    'mother',
    'father'])

print("Pandas dataframe created")
# Out:
# Parsing data...
# All data parsed
# Data imported
# Pandas dataframe created

# %% [markdown]
# ## High-Level Metrics
# This section will give high-level metrics about the people in your database.

# %%
print("How many people in this database?")
print(len(df.index))

print("How many men in this database?")
print(df[df['sex']=='M'].shape[0])

print("How many women in this database?")
print(df[df['sex']=='F'].shape[0])

print("How many non-specified sex in this database?")
print(df[~df['sex'].isin(['F','M'])].shape[0])
# Out:
# How many people in this database?
# 4070
# How many men in this database?
# 2092
# How many women in this database?
# 1930
# How many non-specified sex in this database?
# 48

# %% [markdown]
# ## Places
# This section will give metrics on places in connection to people

# %%
print("Where are people born?")
print(df[~df['birth_place'].str.endswith('alogy')]['birth_place'].value_counts().head(20))
# Out:
# Where are people born?
#                                            3318
# the Ulu-Hema Genealogy (Big Island)          62
# the Ulu-Hema Genealogy (Maui)                40
# Honolulu, Hawaii                             27
# Honolulu, Hi                                 27
# Lahaina, Maui                                24
# the Ulu Genealogy estimated timeline         17
# Hamakua District, Hawaii, Hawaii             16
# Hawaii                                       16
# Niulii, Haw, Hi                              14
# Honolulu, Oahu                               13
# Niu Hawaii                                   11
# Waipio Valley, Haumakua, Hawaii, Hawaii      11
# Waipio Valley, Hamakua, Hawaii                9
# Kailua, Kona, Hawaii, Hawaii                  8
# Lahaina, Maui, Hawaii                         8
# Pololu, Kohala, Hawaii, Hawaii                8
# Hilo, Hawaii                                  7
# Kalopa, Hawaii                                7
# Paauilo, Hamakua, Hawaii, Hawaii              6
# Name: birth_place, dtype: int64

# %%
print("Where are people dying?")
print(df[~df['death_place'].str.endswith('alogy')]['death_place'].value_counts().head(20))
# Out:
# Where are people dying?
#                                            3850
# Honolulu, Hawaii                             31
# Honolulu, Oahu                               22
# Lahaina, Maui                                11
# Honolulu, Hi                                 11
# Waipio Valley, Hamakua, Hawaii                5
# Hilo, Hawaii                                  5
# Honolulu, Honolulu, Hawaii                    4
# Niu Hawaii                                    4
# Kailua, Kona, Hawaii Island                   3
# Honolulu, Oahu,                               3
# Honolulu, Oahu, Hawaii                        3
# Waipio Valley, Haumakua, Hawaii, Hawaii       2
# Kukihaela, Hamakua, Hawaii                    2
# Queen's Hospital, Honolulu, Oahu              2
# Honolulu                                      2
# Paauilo, Hawaii                               2
# Honokaa, Hawaii                               2
# Lapahoehoe, Hawaii, Hawaii                    2
# Maui                                          2
# Name: death_place, dtype: int64

# %% [markdown]
# ## Names
# This section gives you insight into some of the names that exist in your genealogy.

# %%
# What are the most common names?
name_df = df['name'].str.split().str.get(0)
mask = ~name_df.eq('LIVING')
print("What are the most common names?")
print(name_df[mask].value_counts().head(20))
# Out:
# What are the most common names?
# John         42
# William      31
# Elizabeth    21
# Mary         21
# George       20
# Charles      19
# Joseph       13
# Maria        13
# Shaw         13
# Sarah        12
# Henry        12
# David        12
# Annie        11
# Robert       11
# James        11
# Samuel       10
# Edward       10
# Isaac        10
# Albert        8
# Alexander     7
# Name: name, dtype: int64

# %%
print("What are the least common names?")
print(name_df[mask].value_counts().tail(20))
# Out:
# What are the least common names?
# Kumalae               1
# Moku-a-Hualeiakea     1
# Akahiilikapu          1
# Haua                  1
# Kahakumakaliua        1
# Kawaihalaniwailuau    1
# Kapohelemai           1
# Makuakaumanamana      1
# Kanakeawe             1
# Kapukamola            1
# Laieaku               1
# Keakalaulani          1
# Ho'opiliahae          1
# Umiokalani            1
# Hoolaaikaiwi          1
# Kukukalani-o-Pae      1
# Hakaukalalapuakea     1
# Iliilikikuahine       1
# Pupuakea              1
# Kaakau                1
# Name: name, dtype: int64

# %% [markdown]
# ## Health
# This section gives you insight into the life expectancy of your ancestors and family sizes.

# %%
print("What is the average life expectancy?")
print(df['years_lived'].mean())

print("Who lived the longest?")
df.sort_values(by=['years_lived'],ascending=False).head(20)

# TODO: How many people born/died in the same place?

# TODO: Of those who moved, what were the common migration patterns?

# TODO: How did migration patterns change over time?

# TODO: Count of people by century
# Out:
# What is the average life expectancy?
# 54.646408839779006
# Who lived the longest?
#                                                  name   birth_date  \
# 2146                            Ruth Cecilia Mitchell  31 Aug 1891
# 857                               Meli Kahiwa Swinton  24 Jun 1823
# 3762                            Kamakahei (Kamakihei)     ABT 1760
# 2647                                 Naili Pohakukahi  17 Mar 1819
# 1122                  Moses Kahue Kupukaa (Paakahili)   6 Feb 1830
# 258                                   Abbie Bannister  17 Sep 1866
# 301                  Louisa Kekahilinaniopauahi Adams  26 Nov 1888
# 452                   Abigail Kawahinepoaimoku Kaaeae   9 Apr 1875
# 1939                              Charles Reed Bishop  25 Jan 1822
# 1219                                   Mukoi (Makaoi)     ABT 1806
# 3675                         Charlotte Naha Harbottle   3 Jan 1842
# 1933                                       John Young  17 Mar 1744
# 2877                                 Wiiliam Campbell         1788
# 227                                   Alexander Adams  27 Dec 1780
# 3890                       Mary Abigail Kawena Wiggin         1895
# 368                                   Ernest D. Meyer  12 Jul 1891
# 1607                                   Luther Makekau  13 Jul 1898
# 1964                                             Shaw  31 Aug 1867
# 3831                          Grace Haakulo Robertson  23 Jan 1890
# 856   Abel Keliionuuanu (Keliimakekauonuuanu) Makekau   6 Oct 1819
#
#                                      birth_place   death_date  \
# 2146                                 Kola, Kauai  19 Feb 1993
# 857                              Kalae, Moloka’i  21 Apr 1925
# 3762            Hamakua District, Hawaii, Hawaii         1860
# 2647              Palaueka, Holualoa, North Kona  12 Nov 1919
# 1122                Waiapuke, Kohala, Hawaii, HI  10 Nov 1928
# 258                                                1 Jun 1962
# 301                              Heeia, Oahu, Hi  19 Jan 1983
# 452           Kapulena, Hamakua District, Hawaii  15 Sep 1968
# 1939           Glen Falls, Warren, New York, USA   7 Jun 1915
# 1219                      Keokea, Hawaii, Hawaii     ABT 1898
# 3675                                              11 Dec 1933
# 1933  Crosby, Lancashire, England, Great Britain  17 Dec 1835
# 2877                                                     1879
# 227                     Abroath, Angus, Scotland  27 Oct 1871
# 3890                                                     1986
# 368                           Kalae, Molokai, Hi     Oct 1981
# 1607                                Waih’e, Maui  24 Nov 1988
# 1964                         Kaunakakai, Molokai  15 Apr 1956
# 3831                            Honolulu, Hawaii  30 Apr 1979
# 856                 Kailua, Kona, Hawaii, Hawaii  16 Oct 1907
#
#                            death_place sex  child_count  years_lived  \
# 2146                                     M            0        102.0
# 857                      Lahaina, Maui   F           14        102.0
# 3762                                     F            5        100.0
# 2647                                     M            0        100.0
# 1122            Kalaupapa, Molokai, HI   M           13         98.0
# 258                       Honolulu, Hi   F            3         96.0
# 301     St. Francis Hospital, Oahu, Hi   F            0         95.0
# 452   Paauilo, Hamakua, Hawaii, Hawaii   F            0         93.0
# 1939         Berkeley, California, USA   M            0         93.0
# 1219                                     M            8         92.0
# 3675                                     F            0         91.0
# 1933       Kailua, Kona, Hawaii Island   M            7         91.0
# 2877                                     M            1         91.0
# 227                         Niu Hawaii   M           15         91.0
# 3890                                     F            0         91.0
# 368                        Molokai, Hi   M            0         90.0
# 1607                      Hilo, Hawaii   M            0         90.0
# 1964                                     F            0         89.0
# 3831                  Honolulu, Hawaii   F            0         89.0
# 856          Kapulena, Hamakua, Hawaii   M           14         88.0
#
#                                                  mother  \
# 2146                                  Ruth Aulani Mahoe
# 857                          Kaumeaha'ulewaliekahakawai
# 3762
# 2647  Kaupekamoku (Kaupekamoku II, Kaupe-ka-moku, Ka...
# 1122                                 Hiiakaikapoliopele
# 258                             Victoria Kaailama Adams
# 301                                   Anna Kalili Akona
# 452                                  Nawahinelua Mailou
# 1939
# 1219
# 3675                             Kekuialono Palea Kiwai
# 1933
# 2877
# 227                                          Jean Adams
# 3890                             Mary Paahana Kanakaole
# 368
# 1607                                       Mileka Kapoi
# 1964                                          Kuahu'ula
# 3831                                Caroline Hawea Boyd
# 856        Kumiaakea (Kunuiakea, Kekuhemahemaanaaialii)
#
#                                    father
# 2146                 Louis Murie Mitchell
# 857                         Harry Swinton
# 3762
# 2647                           Pohakukahi
# 1122                            Paakahili
# 258                      Andrew Bannister
# 301   Isaac Kapulealii Loakealii Jr Adams
# 452       Timothy Paaluhi Kaaeae (Kaaeoe)
# 1939
# 1219
# 3675               Isaac Kewalo Harbottle
# 1933                         Robert Young
# 2877
# 227                             John Fyfe
# 3890                         Henry Wiggin
# 368
# 1607                    Ramon Hoe Makekau
# 1964                                 Shaw
# 3831           George Humphreys Robertson
# 856                           Naohuleolua

# %%
print("How many children on average did people have?")
print(df['child_count'].mean())

print("Who had the most children??")
df.sort_values(by=['child_count'],ascending=False).head(20)
# Out:
# How many children on average did people have?
# 1.2891891891891891
# Who had the most children??
#                                                    name   birth_date  \
# 488                 Kekaulike Kalani-kui-hono-i-ka-moku
# 909                            Alexander Pollard Hussey   4 Apr 1825
# 576   Ellarene Kapapaihaleonaalii (Papaihaleonaalii)...  12 Nov 1881
# 227                                     Alexander Adams  27 Dec 1780
# 492              Kahekili (II) (Kahekilinuiahumanu III)         1737
# 655                                      Keawenui-a-Umi     ABT 1648
# 940   Kaai-Kaula-Kalei-Kau-Welaha-Makanoe Naweluokek...     ABT 1838
# 856     Abel Keliionuuanu (Keliimakekauonuuanu) Makekau   6 Oct 1819
# 857                                 Meli Kahiwa Swinton  24 Jun 1823
# 1123                            Sarah Kalai Keawehawaii  14 Jun 1857
# 629   Keaweikekahialiiokamoku (Keawe, Keawe-ikekahi-...         1683
# 1122                    Moses Kahue Kupukaa (Paakahili)   6 Feb 1830
# 1748  Kamehameha I the Great (Paiea Kūnuiakea Kameha...     Nov 1737
# 575                                 George Alika Hussey   9 Apr 1879
# 1335  Kauakahiakua (Kauakahiakua I, Kauakahiakua-o-L...         1762
# 240                            Charlotte Oili Harbottle         1813
# 79                                  Umi (Umi-a-Liloa I)     ABT 1626
# 493   Kalaniopu'u (Kaleiopu'u, Kalaninuieiwakamokuka...
# 3701                                             LIVING
# 728                             Piilani (Piilaniwahine)
#
#                                      birth_place   death_date  \
# 488
# 909                     Nantucket, Massachusetts  10 May 1896
# 576                       Waiohinu, Ka'u, Hawaii  28 Feb 1946
# 227                     Abroath, Angus, Scotland  27 Oct 1871
# 492                                                  Jul 1794
# 655                       the Ulu-Hema Genealogy
# 940                       Niulii, Kohala, Hawaii  29 Apr 1916
# 856                 Kailua, Kona, Hawaii, Hawaii  16 Oct 1907
# 857                              Kalae, Moloka’i  21 Apr 1925
# 1123              Pololu, Kohala, Hawaii, Hawaii   9 Oct 1932
# 629
# 1122                Waiapuke, Kohala, Hawaii, HI  10 Nov 1928
# 1748                              Pahoehoe, Maui   8 May 1819
# 575               Waipio Valley, Hamakua, Hawaii   1 Aug 1919
# 1335  Alika, South Kona District, Hawaii, Hawaii
# 240                   Honolulu, Honolulu, Hawaii  23 Sep 1893
# 79           the Ulu-Hema Genealogy (Big Island)
# 493                                                  Apr 1782
# 3701
# 728
#
#                               death_place sex  child_count  years_lived  \
# 488                                         M           18          NaN
# 909                        Kohala, Hawaii   M           16         71.0
# 576                      Honolulu, Hawaii   F           16         65.0
# 227                            Niu Hawaii   M           15         91.0
# 492                 Ulukou, Waikiki, Oahu   M           15         57.0
# 655                                         M           15          NaN
# 940                Niulii, Kohala, Hawaii   F           14         78.0
# 856             Kapulena, Hamakua, Hawaii   M           14         88.0
# 857                         Lahaina, Maui   F           14        102.0
# 1123  Makanikahio, Kohala, Hawaii, Hawaii   F           13         75.0
# 629                                         M           13          NaN
# 1122               Kalaupapa, Molokai, HI   M           13         98.0
# 1748          Kailua, Kona, Hawaii Island   M           12         82.0
# 575        Waipio Valley, Hamakua, Hawaii   M           12         40.0
# 1335                                        M           12          NaN
# 240                        Palama, Hawaii   F           12         80.0
# 79                                          M           12          NaN
# 493                      Waioahukini, Kau   M           12          NaN
# 3701                                        F           11          NaN
# 728                                         F           11          NaN
#
#                                                  mother  \
# 488                                              LIVING
# 909                                 Lydia Emmet Pollard
# 576                    Jeanette Ka'umekekoi Keawepooole
# 227                                          Jean Adams
# 492   Kekuiapoiwa (Kekuaipoiwa I, Kekuiapoiwa Nui , ...
# 655         Kapulani-Nui (Kapukini I, Kapulani-o-Liloa)
# 940                                 Naaiokauahi Opalaau
# 856        Kumiaakea (Kunuiakea, Kekuhemahemaanaaialii)
# 857                          Kaumeaha'ulewaliekahakawai
# 1123                                    Apualaulu Kai-a
# 629    Keakealani (Keakealaniwahine, Keakealani-wahine)
# 1122                                 Hiiakaikapoliopele
# 1748                       Kekuiapoiwa (Kekuiapoiwa II)
# 575                            Ke'a (Kea-aiha) Keaweiwi
# 1335             Kapouhiwa (Kahapoohiwi, Kapoohiioinui)
# 240                       Papapaunauapu (Nauepu, Naapu)
# 79                      Akahiakuleana (Akahi-a-Kuleana)
# 493            Kamakaimoku (Ka-maka'i-moku, Kamakamoku)
# 3701
# 728   Kekaikuihala (Kekaikuihala I, Ke-kai-ku'i-hala...
#
#                                                  father
# 488                 Kaulahea II (Kaulaheanuiokamoku II)
# 909                              Joseph Starbuck Hussey
# 576                        Wahinekona Kaawa (Moi Kaawa)
# 227                                           John Fyfe
# 492                 Kekaulike Kalani-kui-hono-i-ka-moku
# 655                                 Umi (Umi-a-Liloa I)
# 940                                    Naweluokekikipaa
# 856                                         Naohuleolua
# 857                                       Harry Swinton
# 1123                                        Keawehawaii
# 629              Kanalohanauikawela (Keawehanauikawalu)
# 1122                                          Paakahili
# 1748  Keoua Kalanikupuapa'ikalaninui (Keaoua Kalanik...
# 575                                 George Alika Hussey
# 1335  Lonomakaihonua (Lonomakaihonua II, Lonomakaiho...
# 240                                      John Harbottle
# 79                                                Liloa
# 493   Kalaninuiiamamao (Kalani-nui-'i-a-mamao, Ka'i'...
# 3701
# 728       Kalanikaumaka-o-Wakea (Kalanikaumakaowakea I)
